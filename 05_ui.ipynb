# %% [markdown]
# User Interface (UI) Deployment
#
#
# This notebook prepares the trained model for deployment and generates a simple Streamlit user interface to predict Premier League match outcomes.

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '01_loading_cleaning.ipynb', '02_preprocessing.ipynb', '03_eda.ipynb', '04_modeling.ipynb', '05_ui.ipynb', 'best_model.pkl', 'England CSV.csv', 'epl_cleaned.csv', 'model_columns.pkl']

# %% [markdown]
# Streamlit Application File
#
# A Streamlit application (app.py) is created to provide a user-friendly interface.
# The app loads the saved model and allows the user to enter match statistics to generate a prediction.

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\tusar\CET313_EPL_Prototype
